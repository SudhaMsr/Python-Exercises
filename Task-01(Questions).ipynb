# %% [markdown]
# ###

# %% [markdown]
# # Python Exercises For Beginners
# # Task 1

# %% [markdown]
# ### 1. Print "Hello, World!"

# %%
#Question 1--Say "Hello, World!" With Python

# %% [markdown]
# ### 2. Given an integer n, print:
#
# "Weird" if n is odd
#
# "Not Weird" if even and in range 2–5
#
# "Weird" if even and in range 6–20
#
# "Not Weird" if even and > 20
#
# Skill tested: conditional logic, edge cases

# %%
#Question 2--Python If-Else

# %% [markdown]
# ### 3. Read two integers and print:
#
#     sum
#     difference
#     product

# %%
#Question 3--Arithmetic Operators

# %% [markdown]
# ### 4. Given two integers:
#
#     Print integer division (//)
#     Print float division (/)

# %%
#Question 4--Python: Division

# %% [markdown]
# ### 5. Print squares of numbers from 0 to n-1

# %%
#Question 5--Loops

# %% [markdown]
# ### 6. Write a function to check if a year is a leap year.
#
# Rules:
#
#     divisible by 400 → leap
#     divisible by 4 AND not by 100 → leap

# %%
#Question 6--Write a function

# %% [markdown]
# ### 7. Print numbers from 1 to n without spaces or newline

# %%
#Question 7--Print Function
