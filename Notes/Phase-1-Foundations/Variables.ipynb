# %% [markdown]
# #

# %% [markdown]
# # creating variable

# %% [markdown]
# # variables with multi words

# %% [markdown]
# ### Camel case
# - Except the first words, all starts with captial letter

# %%
myVariableName =  'A'

# %% [markdown]
# ### Pascal Case
# - All words starts with capital letter

# %%
MyVariableName = 'A'

# %% [markdown]
# ### Snake case
# - Each word is seperated my underscore character

# %% [markdown]
# ## Assign Multiple Values

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# ## One Value to Multiple Variables

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# ## Unpack a Collection

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Output variables
# - The print() function is often used to output variables.

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %% [markdown]
# - You can also use the + operator to output multiple variables:

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# ## Global Variables
# - A global variable is created outside any function.

# %%
x = "awesome"   # global variable

def myfunc():
    print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %% [markdown]
# - What Happens If You Create Same Name Inside Function?

# %%
x = "awesome"

def myfunc():
    x = "fantastic"   # local variable
    print("Python is " + x)

myfunc()
print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# - Global Keyword

# %%
x = 10

def myfunc():
    global x
    x = 20   # This changes the global variable

myfunc()
print(x)
# Out:
# 20
